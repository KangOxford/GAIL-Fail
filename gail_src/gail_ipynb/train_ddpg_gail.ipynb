# %% [markdown]
# # Train an Agent using Generative Adversarial Imitation Learning
#
# The idea of generative adversarial imitation learning is to train a discriminator network to distinguish between expert trajectories and learner trajectories.
# The learner is trained using a traditional reinforcement learning algorithm such as PPO and is rewarded for trajectories that make the discriminator think that it was an expert trajectory.

# %% [markdown]
# As usual, we first need an expert.
# Note that we now use a variant of the CartPole environment from the seals package, which has fixed episode durations. Read more about why we do this [here](https://imitation.readthedocs.io/en/latest/guide/variable_horizon.html).

# %%
import gym
env = gym.make("Walker2d-v2")

# %%
import numpy as np
from stable_baselines3 import DDPG
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise
n_actions = env.action_space.shape[-1]
action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))
expert = DDPG(
    policy="MlpPolicy",
    env=env,
    action_noise=action_noise, 
    verbose=1,
    seed=0,
    batch_size=64,
    learning_rate=0.05
)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# We generate some expert trajectories, that the discriminator needs to distinguish from the learner's trajectories.

# %%
expert.learn(1e6)  # Note: set to 100000 to train a proficient expert
# expert.learn(1e7)  # Note: set to 100000 to train a proficient expert
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24.2     |
# |    ep_rew_mean     | 5.39     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 5436     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 97       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 52.1     |
# |    ep_rew_mean     | -21.6    |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 409      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 417      |
# | train/             |          |
# |    actor_loss      | 0.748    |
# |    critic_loss     | 0.178    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 222      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 68.2     |
# |    ep_rew_mean     | -35.3    |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 314      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 819      |
# | train/             |          |
# |    actor_loss      | 1.72     |
# |    critic_loss     | 0.362    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 621      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 76.4     |
# |    ep_rew_mean     | -42      |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 294      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 1223     |
# | train/             |          |
# |    actor_loss      | 2.88     |
# |    critic_loss     | 1.15     |
# |    learning_rate   | 0.05     |
# |    n_updates       | 1023     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 81.8     |
# |    ep_rew_mean     | -47.1    |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 284      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 1637     |
# | train/             |          |
# |    actor_loss      | 4.24     |
# |    critic_loss     | 1.08     |
# |    learning_rate   | 0.05     |
# |    n_updates       | 1442     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 85.7     |
# |    ep_rew_mean     | -51.2    |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 277      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2056     |
# | train/             |          |
# |    actor_loss      | 5.42     |
# |    critic_loss     | 0.827    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 1856     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 87.9     |
# |    ep_rew_mean     | -52.6    |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 272      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2460     |
# | train/             |          |
# |    actor_loss      | 6.47     |
# |    critic_loss     | 2.24     |
# |    learning_rate   | 0.05     |
# |    n_updates       | 2260     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 89.9     |
# |    ep_rew_mean     | -54.8    |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 269      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 2876     |
# | train/             |          |
# |    actor_loss      | 7.68     |
# |    critic_loss     | 1.39     |
# |    learning_rate   | 0.05     |
# |    n_updates       | 2676     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 90.8     |
# |    ep_rew_mean     | -55.1    |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 268      |
# |    time_elapsed    | 12       |
# |    total_timesteps | 3270     |
# | train/             |          |
# |    actor_loss      | 8.55     |
# |    critic_loss     | 1.34     |
# |    learning_rate   | 0.05     |
# |    n_updates       | 3075     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 91.7     |
# |    ep_rew_mean     | -55.5    |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 265      |
# |    time_elapsed    | 13       |
# |    total_timesteps | 3668     |
# | train/             |          |
# |    actor_loss      | 9.41     |
# |    critic_loss     | 3.89     |
# |    learning_rate   | 0.05     |
# |    n_updates       | 3472     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 92.6     |
# |    ep_rew_mean     | -56.4    |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 263      |
# |    time_elapsed    | 15       |
# |    total_timesteps | 4076     |
# | train/             |          |
# |    actor_loss      | 10.3     |
# |    critic_loss     | 1.85     |
# |    learning_rate   | 0.05     |
# |    n_updates       | 3878     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 93.4     |
# |    ep_rew_mean     | -57.1    |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 263      |
# |    time_elapsed    | 17       |
# |    total_timesteps | 4484     |
# | train/             |          |
# |    actor_loss      | 11.4     |
# |    critic_loss     | 1.2      |
# |    learning_rate   | 0.05     |
# |    n_updates       | 4285     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 94.1     |
# |    ep_rew_mean     | -57.9    |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 262      |
# |    time_elapsed    | 18       |
# |    total_timesteps | 4893     |
# | train/             |          |
# |    actor_loss      | 12.4     |
# |    critic_loss     | 0.824    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 4697     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 94.6     |
# |    ep_rew_mean     | -58.2    |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 262      |
# |    time_elapsed    | 20       |
# |    total_timesteps | 5295     |
# | train/             |          |
# |    actor_loss      | 13.6     |
# |    critic_loss     | 1.21     |
# |    learning_rate   | 0.05     |
# |    n_updates       | 5103     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 95.2     |
# |    ep_rew_mean     | -58.7    |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 262      |
# |    time_elapsed    | 21       |
# |    total_timesteps | 5709     |
# | train/             |          |
# |    actor_loss      | 14.7     |
# |    critic_loss     | 2.44     |
# |    learning_rate   | 0.05     |
# |    n_updates       | 5508     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 95.7     |
# |    ep_rew_mean     | -59.4    |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 261      |
# |    time_elapsed    | 23       |
# |    total_timesteps | 6122     |
# | train/             |          |
# |    actor_loss      | 15.5     |
# |    critic_loss     | 1.23     |
# |    learning_rate   | 0.05     |
# |    n_updates       | 5923     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 96       |
# |    ep_rew_mean     | -59.4    |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 260      |
# |    time_elapsed    | 25       |
# |    total_timesteps | 6525     |
# | train/             |          |
# |    actor_loss      | 16.4     |
# |    critic_loss     | 1.16     |
# |    learning_rate   | 0.05     |
# |    n_updates       | 6330     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 96.2     |
# |    ep_rew_mean     | -59.4    |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 260      |
# |    time_elapsed    | 26       |
# |    total_timesteps | 6924     |
# | train/             |          |
# |    actor_loss      | 17.6     |
# |    critic_loss     | 1.6      |
# |    learning_rate   | 0.05     |
# |    n_updates       | 6724     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 96.4     |
# |    ep_rew_mean     | -59.4    |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 258      |
# |    time_elapsed    | 28       |
# |    total_timesteps | 7328     |
# | train/             |          |
# |    actor_loss      | 18.4     |
# |    critic_loss     | 0.709    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 7125     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 96.6     |
# |    ep_rew_mean     | -59.4    |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 257      |
# |    time_elapsed    | 30       |
# |    total_timesteps | 7728     |
# | train/             |          |
# |    actor_loss      | 19.4     |
# |    critic_loss     | 0.866    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 7538     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 96.9     |
# |    ep_rew_mean     | -59.6    |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 256      |
# |    time_elapsed    | 31       |
# |    total_timesteps | 8138     |
# | train/             |          |
# |    actor_loss      | 20.3     |
# |    critic_loss     | 1.04     |
# |    learning_rate   | 0.05     |
# |    n_updates       | 7939     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 97.1     |
# |    ep_rew_mean     | -59.8    |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 256      |
# |    time_elapsed    | 33       |
# |    total_timesteps | 8546     |
# | train/             |          |
# |    actor_loss      | 21.6     |
# |    critic_loss     | 0.699    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 8352     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 97.3     |
# |    ep_rew_mean     | -60      |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 256      |
# |    time_elapsed    | 34       |
# |    total_timesteps | 8954     |
# | train/             |          |
# |    actor_loss      | 21.9     |
# |    critic_loss     | 0.62     |
# |    learning_rate   | 0.05     |
# |    n_updates       | 8750     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 97.5     |
# |    ep_rew_mean     | -60.2    |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 256      |
# |    time_elapsed    | 36       |
# |    total_timesteps | 9360     |
# | train/             |          |
# |    actor_loss      | 22.9     |
# |    critic_loss     | 0.688    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 9163     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 97.6     |
# |    ep_rew_mean     | -60.1    |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 256      |
# |    time_elapsed    | 38       |
# |    total_timesteps | 9760     |
# | train/             |          |
# |    actor_loss      | 23.3     |
# |    critic_loss     | 0.742    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 9561     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -62.8    |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 255      |
# |    time_elapsed    | 39       |
# |    total_timesteps | 10166    |
# | train/             |          |
# |    actor_loss      | 23.9     |
# |    critic_loss     | 1.49     |
# |    learning_rate   | 0.05     |
# |    n_updates       | 9964     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -63.4    |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 255      |
# |    time_elapsed    | 41       |
# |    total_timesteps | 10573    |
# | train/             |          |
# |    actor_loss      | 24.4     |
# |    critic_loss     | 0.707    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 10373    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -63.3    |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 255      |
# |    time_elapsed    | 42       |
# |    total_timesteps | 10973    |
# | train/             |          |
# |    actor_loss      | 25       |
# |    critic_loss     | 2.34     |
# |    learning_rate   | 0.05     |
# |    n_updates       | 10774    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -63.4    |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 255      |
# |    time_elapsed    | 44       |
# |    total_timesteps | 11382    |
# | train/             |          |
# |    actor_loss      | 25.5     |
# |    critic_loss     | 0.721    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 11180    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -63.2    |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 255      |
# |    time_elapsed    | 46       |
# |    total_timesteps | 11786    |
# | train/             |          |
# |    actor_loss      | 26.1     |
# |    critic_loss     | 0.674    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 11588    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -62.8    |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 255      |
# |    time_elapsed    | 47       |
# |    total_timesteps | 12191    |
# | train/             |          |
# |    actor_loss      | 26.7     |
# |    critic_loss     | 0.704    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 11996    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -63.1    |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 255      |
# |    time_elapsed    | 49       |
# |    total_timesteps | 12602    |
# | train/             |          |
# |    actor_loss      | 26.9     |
# |    critic_loss     | 0.744    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 12404    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -62.8    |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 253      |
# |    time_elapsed    | 51       |
# |    total_timesteps | 13008    |
# | train/             |          |
# |    actor_loss      | 27.6     |
# |    critic_loss     | 1.34     |
# |    learning_rate   | 0.05     |
# |    n_updates       | 12807    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -63.3    |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 252      |
# |    time_elapsed    | 53       |
# |    total_timesteps | 13427    |
# | train/             |          |
# |    actor_loss      | 27.9     |
# |    critic_loss     | 0.743    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 13225    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -63.6    |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 251      |
# |    time_elapsed    | 54       |
# |    total_timesteps | 13833    |
# | train/             |          |
# |    actor_loss      | 28       |
# |    critic_loss     | 2.86     |
# |    learning_rate   | 0.05     |
# |    n_updates       | 13641    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -63.4    |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 250      |
# |    time_elapsed    | 56       |
# |    total_timesteps | 14233    |
# | train/             |          |
# |    actor_loss      | 28.1     |
# |    critic_loss     | 0.683    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 14032    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -63.4    |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 249      |
# |    time_elapsed    | 58       |
# |    total_timesteps | 14643    |
# | train/             |          |
# |    actor_loss      | 28.7     |
# |    critic_loss     | 0.484    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 14449    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -63.6    |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 248      |
# |    time_elapsed    | 60       |
# |    total_timesteps | 15060    |
# | train/             |          |
# |    actor_loss      | 29.1     |
# |    critic_loss     | 0.598    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 14863    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -63.3    |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 248      |
# |    time_elapsed    | 62       |
# |    total_timesteps | 15453    |
# | train/             |          |
# |    actor_loss      | 29.1     |
# |    critic_loss     | 0.799    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 15259    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -63.1    |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 247      |
# |    time_elapsed    | 64       |
# |    total_timesteps | 15858    |
# | train/             |          |
# |    actor_loss      | 29.6     |
# |    critic_loss     | 0.856    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 15659    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -62.6    |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 244      |
# |    time_elapsed    | 66       |
# |    total_timesteps | 16257    |
# | train/             |          |
# |    actor_loss      | 30.1     |
# |    critic_loss     | 0.792    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 16064    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -62.8    |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 243      |
# |    time_elapsed    | 68       |
# |    total_timesteps | 16666    |
# | train/             |          |
# |    actor_loss      | 30.4     |
# |    critic_loss     | 0.715    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 16470    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -63      |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 243      |
# |    time_elapsed    | 70       |
# |    total_timesteps | 17068    |
# | train/             |          |
# |    actor_loss      | 30.6     |
# |    critic_loss     | 0.624    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 16867    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -63.2    |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 243      |
# |    time_elapsed    | 71       |
# |    total_timesteps | 17477    |
# | train/             |          |
# |    actor_loss      | 30.9     |
# |    critic_loss     | 0.964    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 17282    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -63.6    |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 242      |
# |    time_elapsed    | 73       |
# |    total_timesteps | 17891    |
# | train/             |          |
# |    actor_loss      | 31.2     |
# |    critic_loss     | 1.42     |
# |    learning_rate   | 0.05     |
# |    n_updates       | 17689    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -63.6    |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 241      |
# |    time_elapsed    | 75       |
# |    total_timesteps | 18297    |
# | train/             |          |
# |    actor_loss      | 31.5     |
# |    critic_loss     | 0.566    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 18102    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -63.7    |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 241      |
# |    time_elapsed    | 77       |
# |    total_timesteps | 18713    |
# | train/             |          |
# |    actor_loss      | 31.9     |
# |    critic_loss     | 1.21     |
# |    learning_rate   | 0.05     |
# |    n_updates       | 18509    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -63.7    |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 240      |
# |    time_elapsed    | 79       |
# |    total_timesteps | 19119    |
# | train/             |          |
# |    actor_loss      | 31.9     |
# |    critic_loss     | 1.81     |
# |    learning_rate   | 0.05     |
# |    n_updates       | 18921    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -63.9    |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 240      |
# |    time_elapsed    | 81       |
# |    total_timesteps | 19528    |
# | train/             |          |
# |    actor_loss      | 31.9     |
# |    critic_loss     | 1.71     |
# |    learning_rate   | 0.05     |
# |    n_updates       | 19329    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -64.3    |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 239      |
# |    time_elapsed    | 83       |
# |    total_timesteps | 19946    |
# | train/             |          |
# |    actor_loss      | 32       |
# |    critic_loss     | 1.76     |
# |    learning_rate   | 0.05     |
# |    n_updates       | 19746    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -64.6    |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 239      |
# |    time_elapsed    | 85       |
# |    total_timesteps | 20365    |
# | train/             |          |
# |    actor_loss      | 32.2     |
# |    critic_loss     | 0.81     |
# |    learning_rate   | 0.05     |
# |    n_updates       | 20165    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -64.5    |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 239      |
# |    time_elapsed    | 86       |
# |    total_timesteps | 20768    |
# | train/             |          |
# |    actor_loss      | 32.6     |
# |    critic_loss     | 0.995    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 20566    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -64.5    |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 238      |
# |    time_elapsed    | 88       |
# |    total_timesteps | 21171    |
# | train/             |          |
# |    actor_loss      | 32.4     |
# |    critic_loss     | 0.991    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 20972    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -64.4    |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 238      |
# |    time_elapsed    | 90       |
# |    total_timesteps | 21569    |
# | train/             |          |
# |    actor_loss      | 32.5     |
# |    critic_loss     | 1.37     |
# |    learning_rate   | 0.05     |
# |    n_updates       | 21375    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -64.4    |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 237      |
# |    time_elapsed    | 92       |
# |    total_timesteps | 21974    |
# | train/             |          |
# |    actor_loss      | 32.3     |
# |    critic_loss     | 0.784    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 21770    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -64.3    |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 237      |
# |    time_elapsed    | 94       |
# |    total_timesteps | 22379    |
# | train/             |          |
# |    actor_loss      | 32.6     |
# |    critic_loss     | 6.61     |
# |    learning_rate   | 0.05     |
# |    n_updates       | 22178    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -64.3    |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 236      |
# |    time_elapsed    | 96       |
# |    total_timesteps | 22797    |
# | train/             |          |
# |    actor_loss      | 31.8     |
# |    critic_loss     | 2.14     |
# |    learning_rate   | 0.05     |
# |    n_updates       | 22596    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -64.3    |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 236      |
# |    time_elapsed    | 98       |
# |    total_timesteps | 23201    |
# | train/             |          |
# |    actor_loss      | 31.8     |
# |    critic_loss     | 1.43     |
# |    learning_rate   | 0.05     |
# |    n_updates       | 23000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -64.3    |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 235      |
# |    time_elapsed    | 100      |
# |    total_timesteps | 23617    |
# | train/             |          |
# |    actor_loss      | 32       |
# |    critic_loss     | 1.03     |
# |    learning_rate   | 0.05     |
# |    n_updates       | 23415    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -64.4    |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 235      |
# |    time_elapsed    | 101      |
# |    total_timesteps | 24033    |
# | train/             |          |
# |    actor_loss      | 31.9     |
# |    critic_loss     | 1.28     |
# |    learning_rate   | 0.05     |
# |    n_updates       | 23832    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -64.6    |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 235      |
# |    time_elapsed    | 103      |
# |    total_timesteps | 24444    |
# | train/             |          |
# |    actor_loss      | 32.1     |
# |    critic_loss     | 0.823    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 24243    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -64.5    |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 235      |
# |    time_elapsed    | 105      |
# |    total_timesteps | 24850    |
# | train/             |          |
# |    actor_loss      | 31.9     |
# |    critic_loss     | 1.05     |
# |    learning_rate   | 0.05     |
# |    n_updates       | 24651    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -64      |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 234      |
# |    time_elapsed    | 107      |
# |    total_timesteps | 25249    |
# | train/             |          |
# |    actor_loss      | 32       |
# |    critic_loss     | 1.05     |
# |    learning_rate   | 0.05     |
# |    n_updates       | 25049    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -64.5    |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 234      |
# |    time_elapsed    | 109      |
# |    total_timesteps | 25661    |
# | train/             |          |
# |    actor_loss      | 31.9     |
# |    critic_loss     | 1.15     |
# |    learning_rate   | 0.05     |
# |    n_updates       | 25460    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -64.5    |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 234      |
# |    time_elapsed    | 111      |
# |    total_timesteps | 26066    |
# | train/             |          |
# |    actor_loss      | 32       |
# |    critic_loss     | 0.657    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 25872    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -64.9    |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 234      |
# |    time_elapsed    | 113      |
# |    total_timesteps | 26475    |
# | train/             |          |
# |    actor_loss      | 32       |
# |    critic_loss     | 0.639    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 26279    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -64.8    |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 233      |
# |    time_elapsed    | 114      |
# |    total_timesteps | 26880    |
# | train/             |          |
# |    actor_loss      | 32.1     |
# |    critic_loss     | 0.402    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 26681    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -65.1    |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 233      |
# |    time_elapsed    | 116      |
# |    total_timesteps | 27299    |
# | train/             |          |
# |    actor_loss      | 32       |
# |    critic_loss     | 0.604    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 27098    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -65.2    |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 233      |
# |    time_elapsed    | 118      |
# |    total_timesteps | 27710    |
# | train/             |          |
# |    actor_loss      | 32.2     |
# |    critic_loss     | 0.843    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 27509    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -65      |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 233      |
# |    time_elapsed    | 120      |
# |    total_timesteps | 28121    |
# | train/             |          |
# |    actor_loss      | 32.2     |
# |    critic_loss     | 0.635    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 27918    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -65.3    |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 233      |
# |    time_elapsed    | 122      |
# |    total_timesteps | 28542    |
# | train/             |          |
# |    actor_loss      | 32.2     |
# |    critic_loss     | 0.5      |
# |    learning_rate   | 0.05     |
# |    n_updates       | 28345    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -65.3    |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 233      |
# |    time_elapsed    | 124      |
# |    total_timesteps | 28959    |
# | train/             |          |
# |    actor_loss      | 32.3     |
# |    critic_loss     | 0.652    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 28758    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -65.4    |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 233      |
# |    time_elapsed    | 126      |
# |    total_timesteps | 29371    |
# | train/             |          |
# |    actor_loss      | 32.5     |
# |    critic_loss     | 0.962    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 29168    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -65.2    |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 232      |
# |    time_elapsed    | 127      |
# |    total_timesteps | 29778    |
# | train/             |          |
# |    actor_loss      | 32.7     |
# |    critic_loss     | 0.588    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 29577    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -65      |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 232      |
# |    time_elapsed    | 129      |
# |    total_timesteps | 30188    |
# | train/             |          |
# |    actor_loss      | 32.6     |
# |    critic_loss     | 1.1      |
# |    learning_rate   | 0.05     |
# |    n_updates       | 29991    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -65.1    |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 232      |
# |    time_elapsed    | 131      |
# |    total_timesteps | 30607    |
# | train/             |          |
# |    actor_loss      | 32.7     |
# |    critic_loss     | 0.839    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 30405    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -65.1    |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 232      |
# |    time_elapsed    | 133      |
# |    total_timesteps | 31008    |
# | train/             |          |
# |    actor_loss      | 32.6     |
# |    critic_loss     | 0.666    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 30809    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -65.3    |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 233      |
# |    time_elapsed    | 134      |
# |    total_timesteps | 31419    |
# | train/             |          |
# |    actor_loss      | 32.6     |
# |    critic_loss     | 0.753    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 31220    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -65.5    |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 233      |
# |    time_elapsed    | 136      |
# |    total_timesteps | 31826    |
# | train/             |          |
# |    actor_loss      | 32.6     |
# |    critic_loss     | 0.545    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 31629    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -65.9    |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 233      |
# |    time_elapsed    | 138      |
# |    total_timesteps | 32248    |
# | train/             |          |
# |    actor_loss      | 32.7     |
# |    critic_loss     | 0.643    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 32044    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -66      |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 233      |
# |    time_elapsed    | 139      |
# |    total_timesteps | 32658    |
# | train/             |          |
# |    actor_loss      | 32.8     |
# |    critic_loss     | 1.17     |
# |    learning_rate   | 0.05     |
# |    n_updates       | 32462    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -65.9    |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 233      |
# |    time_elapsed    | 141      |
# |    total_timesteps | 33067    |
# | train/             |          |
# |    actor_loss      | 33.1     |
# |    critic_loss     | 0.745    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 32866    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -65.9    |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 233      |
# |    time_elapsed    | 143      |
# |    total_timesteps | 33472    |
# | train/             |          |
# |    actor_loss      | 33.2     |
# |    critic_loss     | 0.702    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 33270    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -65.8    |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 234      |
# |    time_elapsed    | 144      |
# |    total_timesteps | 33886    |
# | train/             |          |
# |    actor_loss      | 33.1     |
# |    critic_loss     | 0.405    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 33685    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -65.9    |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 234      |
# |    time_elapsed    | 146      |
# |    total_timesteps | 34305    |
# | train/             |          |
# |    actor_loss      | 33       |
# |    critic_loss     | 0.571    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 34103    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -65.9    |
# | time/              |          |
# |    episodes        | 344      |
# |    fps             | 234      |
# |    time_elapsed    | 148      |
# |    total_timesteps | 34719    |
# | train/             |          |
# |    actor_loss      | 32.9     |
# |    critic_loss     | 169      |
# |    learning_rate   | 0.05     |
# |    n_updates       | 34517    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -66      |
# | time/              |          |
# |    episodes        | 348      |
# |    fps             | 234      |
# |    time_elapsed    | 149      |
# |    total_timesteps | 35130    |
# | train/             |          |
# |    actor_loss      | 32.9     |
# |    critic_loss     | 1.59     |
# |    learning_rate   | 0.05     |
# |    n_updates       | 34934    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -66.4    |
# | time/              |          |
# |    episodes        | 352      |
# |    fps             | 234      |
# |    time_elapsed    | 151      |
# |    total_timesteps | 35544    |
# | train/             |          |
# |    actor_loss      | 32.4     |
# |    critic_loss     | 1.23     |
# |    learning_rate   | 0.05     |
# |    n_updates       | 35336    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -66.4    |
# | time/              |          |
# |    episodes        | 356      |
# |    fps             | 235      |
# |    time_elapsed    | 152      |
# |    total_timesteps | 35957    |
# | train/             |          |
# |    actor_loss      | 32.4     |
# |    critic_loss     | 1.6      |
# |    learning_rate   | 0.05     |
# |    n_updates       | 35761    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -66.6    |
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 235      |
# |    time_elapsed    | 154      |
# |    total_timesteps | 36367    |
# | train/             |          |
# |    actor_loss      | 32.3     |
# |    critic_loss     | 0.824    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 36169    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -66.8    |
# | time/              |          |
# |    episodes        | 364      |
# |    fps             | 235      |
# |    time_elapsed    | 156      |
# |    total_timesteps | 36785    |
# | train/             |          |
# |    actor_loss      | 32       |
# |    critic_loss     | 1.07     |
# |    learning_rate   | 0.05     |
# |    n_updates       | 36582    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -66.8    |
# | time/              |          |
# |    episodes        | 368      |
# |    fps             | 235      |
# |    time_elapsed    | 157      |
# |    total_timesteps | 37190    |
# | train/             |          |
# |    actor_loss      | 32.6     |
# |    critic_loss     | 0.606    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 36995    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -66.5    |
# | time/              |          |
# |    episodes        | 372      |
# |    fps             | 235      |
# |    time_elapsed    | 159      |
# |    total_timesteps | 37596    |
# | train/             |          |
# |    actor_loss      | 32.5     |
# |    critic_loss     | 0.708    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 37399    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -66.3    |
# | time/              |          |
# |    episodes        | 376      |
# |    fps             | 236      |
# |    time_elapsed    | 160      |
# |    total_timesteps | 38000    |
# | train/             |          |
# |    actor_loss      | 32.5     |
# |    critic_loss     | 0.563    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 37808    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -66.3    |
# | time/              |          |
# |    episodes        | 380      |
# ...
# |    actor_loss      | 32.9     |
# |    critic_loss     | 0.361    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 987194   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -66.3    |
# | time/              |          |
# |    episodes        | 9676     |
# |    fps             | 204      |
# |    time_elapsed    | 4819     |
# |    total_timesteps | 987797   |
# | train/             |          |
# |    actor_loss      | 32.8     |
# |    critic_loss     | 0.321    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 987598   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -66.3    |
# | time/              |          |
# |    episodes        | 9680     |
# |    fps             | 204      |
# |    time_elapsed    | 4821     |
# |    total_timesteps | 988194   |
# | train/             |          |
# |    actor_loss      | 32.9     |
# |    critic_loss     | 0.353    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 987993   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -66.6    |
# | time/              |          |
# |    episodes        | 9684     |
# |    fps             | 204      |
# |    time_elapsed    | 4823     |
# |    total_timesteps | 988611   |
# | train/             |          |
# |    actor_loss      | 32.9     |
# |    critic_loss     | 0.364    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 988407   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -66.2    |
# | time/              |          |
# |    episodes        | 9688     |
# |    fps             | 204      |
# |    time_elapsed    | 4825     |
# |    total_timesteps | 989013   |
# | train/             |          |
# |    actor_loss      | 32.7     |
# |    critic_loss     | 0.393    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 988818   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -66.4    |
# | time/              |          |
# |    episodes        | 9692     |
# |    fps             | 204      |
# |    time_elapsed    | 4827     |
# |    total_timesteps | 989433   |
# | train/             |          |
# |    actor_loss      | 32.9     |
# |    critic_loss     | 0.355    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 989227   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -65.8    |
# | time/              |          |
# |    episodes        | 9696     |
# |    fps             | 204      |
# |    time_elapsed    | 4829     |
# |    total_timesteps | 989827   |
# | train/             |          |
# |    actor_loss      | 32.9     |
# |    critic_loss     | 0.403    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 989636   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -66      |
# | time/              |          |
# |    episodes        | 9700     |
# |    fps             | 204      |
# |    time_elapsed    | 4831     |
# |    total_timesteps | 990237   |
# | train/             |          |
# |    actor_loss      | 32.9     |
# |    critic_loss     | 0.366    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 990038   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -65.9    |
# | time/              |          |
# |    episodes        | 9704     |
# |    fps             | 204      |
# |    time_elapsed    | 4833     |
# |    total_timesteps | 990641   |
# | train/             |          |
# |    actor_loss      | 32.9     |
# |    critic_loss     | 0.534    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 990439   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -65.6    |
# | time/              |          |
# |    episodes        | 9708     |
# |    fps             | 204      |
# |    time_elapsed    | 4835     |
# |    total_timesteps | 991036   |
# | train/             |          |
# |    actor_loss      | 33       |
# |    critic_loss     | 0.392    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 990837   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -64.9    |
# | time/              |          |
# |    episodes        | 9712     |
# |    fps             | 204      |
# |    time_elapsed    | 4837     |
# |    total_timesteps | 991429   |
# | train/             |          |
# |    actor_loss      | 33       |
# |    critic_loss     | 0.359    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 991234   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -64.6    |
# | time/              |          |
# |    episodes        | 9716     |
# |    fps             | 204      |
# |    time_elapsed    | 4839     |
# |    total_timesteps | 991828   |
# | train/             |          |
# |    actor_loss      | 33       |
# |    critic_loss     | 0.412    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 991628   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -64.8    |
# | time/              |          |
# |    episodes        | 9720     |
# |    fps             | 204      |
# |    time_elapsed    | 4841     |
# |    total_timesteps | 992238   |
# | train/             |          |
# |    actor_loss      | 32.9     |
# |    critic_loss     | 0.321    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 992037   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -65      |
# | time/              |          |
# |    episodes        | 9724     |
# |    fps             | 204      |
# |    time_elapsed    | 4843     |
# |    total_timesteps | 992654   |
# | train/             |          |
# |    actor_loss      | 33       |
# |    critic_loss     | 0.321    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 992456   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -65      |
# | time/              |          |
# |    episodes        | 9728     |
# |    fps             | 204      |
# |    time_elapsed    | 4845     |
# |    total_timesteps | 993064   |
# | train/             |          |
# |    actor_loss      | 33       |
# |    critic_loss     | 0.31     |
# |    learning_rate   | 0.05     |
# |    n_updates       | 992866   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -65      |
# | time/              |          |
# |    episodes        | 9732     |
# |    fps             | 204      |
# |    time_elapsed    | 4847     |
# |    total_timesteps | 993473   |
# | train/             |          |
# |    actor_loss      | 33.1     |
# |    critic_loss     | 0.399    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 993272   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -64.7    |
# | time/              |          |
# |    episodes        | 9736     |
# |    fps             | 204      |
# |    time_elapsed    | 4849     |
# |    total_timesteps | 993883   |
# | train/             |          |
# |    actor_loss      | 33       |
# |    critic_loss     | 0.537    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 993679   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -64.5    |
# | time/              |          |
# |    episodes        | 9740     |
# |    fps             | 204      |
# |    time_elapsed    | 4851     |
# |    total_timesteps | 994289   |
# | train/             |          |
# |    actor_loss      | 33.1     |
# |    critic_loss     | 0.529    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 994088   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -64.6    |
# | time/              |          |
# |    episodes        | 9744     |
# |    fps             | 204      |
# |    time_elapsed    | 4853     |
# |    total_timesteps | 994698   |
# | train/             |          |
# |    actor_loss      | 33       |
# |    critic_loss     | 0.343    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 994504   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -64.4    |
# | time/              |          |
# |    episodes        | 9748     |
# |    fps             | 204      |
# |    time_elapsed    | 4855     |
# |    total_timesteps | 995112   |
# | train/             |          |
# |    actor_loss      | 33.1     |
# |    critic_loss     | 0.362    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 994911   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -64.3    |
# | time/              |          |
# |    episodes        | 9752     |
# |    fps             | 204      |
# |    time_elapsed    | 4857     |
# |    total_timesteps | 995524   |
# | train/             |          |
# |    actor_loss      | 33.2     |
# |    critic_loss     | 0.301    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 995325   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -64.4    |
# | time/              |          |
# |    episodes        | 9756     |
# |    fps             | 204      |
# |    time_elapsed    | 4859     |
# |    total_timesteps | 995939   |
# | train/             |          |
# |    actor_loss      | 33       |
# |    critic_loss     | 0.52     |
# |    learning_rate   | 0.05     |
# |    n_updates       | 995740   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -64.2    |
# | time/              |          |
# |    episodes        | 9760     |
# |    fps             | 204      |
# |    time_elapsed    | 4861     |
# |    total_timesteps | 996345   |
# | train/             |          |
# |    actor_loss      | 32.9     |
# |    critic_loss     | 0.343    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 996150   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -64.1    |
# | time/              |          |
# |    episodes        | 9764     |
# |    fps             | 204      |
# |    time_elapsed    | 4863     |
# |    total_timesteps | 996755   |
# | train/             |          |
# |    actor_loss      | 33.3     |
# |    critic_loss     | 0.359    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 996557   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -64.2    |
# | time/              |          |
# |    episodes        | 9768     |
# |    fps             | 204      |
# |    time_elapsed    | 4865     |
# |    total_timesteps | 997166   |
# | train/             |          |
# |    actor_loss      | 33       |
# |    critic_loss     | 0.368    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 996965   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -64.3    |
# | time/              |          |
# |    episodes        | 9772     |
# |    fps             | 204      |
# |    time_elapsed    | 4867     |
# |    total_timesteps | 997583   |
# | train/             |          |
# |    actor_loss      | 33       |
# |    critic_loss     | 0.392    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 997382   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -64.2    |
# | time/              |          |
# |    episodes        | 9776     |
# |    fps             | 204      |
# |    time_elapsed    | 4869     |
# |    total_timesteps | 997987   |
# | train/             |          |
# |    actor_loss      | 33       |
# |    critic_loss     | 0.371    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 997788   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -64.6    |
# | time/              |          |
# |    episodes        | 9780     |
# |    fps             | 204      |
# |    time_elapsed    | 4871     |
# |    total_timesteps | 998402   |
# | train/             |          |
# |    actor_loss      | 32.9     |
# |    critic_loss     | 0.325    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 998199   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -64.3    |
# | time/              |          |
# |    episodes        | 9784     |
# |    fps             | 204      |
# |    time_elapsed    | 4873     |
# |    total_timesteps | 998808   |
# | train/             |          |
# |    actor_loss      | 32.9     |
# |    critic_loss     | 0.413    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 998607   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -64.5    |
# | time/              |          |
# |    episodes        | 9788     |
# |    fps             | 204      |
# |    time_elapsed    | 4875     |
# |    total_timesteps | 999213   |
# | train/             |          |
# |    actor_loss      | 33       |
# |    critic_loss     | 0.39     |
# |    learning_rate   | 0.05     |
# |    n_updates       | 999014   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -64.3    |
# | time/              |          |
# |    episodes        | 9792     |
# |    fps             | 204      |
# |    time_elapsed    | 4877     |
# |    total_timesteps | 999624   |
# | train/             |          |
# |    actor_loss      | 33       |
# |    critic_loss     | 0.409    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 999424   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -64.5    |
# | time/              |          |
# |    episodes        | 9796     |
# |    fps             | 204      |
# |    time_elapsed    | 4879     |
# |    total_timesteps | 1000028  |
# | train/             |          |
# |    actor_loss      | 33       |
# |    critic_loss     | 0.375    |
# |    learning_rate   | 0.05     |
# |    n_updates       | 999830   |
# ---------------------------------

# %%
from imitation.data import rollout
from imitation.data.wrappers import RolloutInfoWrapper
from stable_baselines3.common.vec_env import DummyVecEnv

rollouts = rollout.rollout(
    expert,
    DummyVecEnv([lambda: RolloutInfoWrapper(gym.make("seals/CartPole-v0"))] * 5),
    rollout.make_sample_until(min_timesteps=None, min_episodes=60),
)
# Out:
# /Users/kang/opt/anaconda3/lib/python3.9/site-packages/gym/spaces/box.py:73: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(

# %% [markdown]
# Now we are ready to set up our GAIL trainer.
# Note, that the `reward_net` is actually the network of the discriminator.
# We evaluate the learner before and after training so we can see if it made any progress.

# %%
from imitation.algorithms.adversarial.gail import GAIL
from imitation.rewards.reward_nets import BasicRewardNet
from imitation.util.networks import RunningNorm
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv

import gym
import seals


venv = DummyVecEnv([lambda: gym.make("seals/CartPole-v0")] * 8)
learner = PPO(
    env=venv,
    policy=MlpPolicy,
    batch_size=64,
    ent_coef=0.0,
    learning_rate=0.0003,
    n_epochs=10,
)
reward_net = BasicRewardNet(
    venv.observation_space, venv.action_space, normalize_input_layer=RunningNorm
)
gail_trainer = GAIL(
    demonstrations=rollouts,
    demo_batch_size=1024,
    gen_replay_buffer_capacity=2048,
    n_disc_updates_per_round=4,
    venv=venv,
    gen_algo=learner,
    reward_net=reward_net,
)

learner_rewards_before_training, _ = evaluate_policy(
    learner, venv, 100, return_episode_rewards=True
)
gail_trainer.train(20000)  # Note: set to 300000 for better results
learner_rewards_after_training, _ = evaluate_policy(
    learner, venv, 100, return_episode_rewards=True
)

# %% [markdown]
# When we look at the histograms of rewards before and after learning, we can see that the learner is not perfect yet, but it made some progress at least.
# If not, just re-run the above cell.

# %%
import matplotlib.pyplot as plt
import numpy as np

print(np.mean(learner_rewards_after_training))
print(np.mean(learner_rewards_before_training))

plt.hist(
    [learner_rewards_before_training, learner_rewards_after_training],
    label=["untrained", "trained"],
)
plt.legend()
plt.show()
