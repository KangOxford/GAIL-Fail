# %% [markdown]
# #  Walker2d-v2
#
# 1) generate the policy for finding the return
# 2) generate the h5 file for training

# %% [markdown]
# # connect to github

# %%
# !python --version
# Out:
# Python 3.7.13

# %%
pip install free-mujoco-py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 14.1 MB 4.0 MB/s
# ...
#      |████████████████████████████████| 203 kB 66.5 MB/s
# ...

# %%
# Mount Google Drive
from google.colab import drive # import drive from google colab

ROOT = "/content/drive"     # default location for the drive
print(ROOT)                 # print content of ROOT (Optional)

drive.mount(ROOT)           # we mount the google drive at /content/drive
# Out:
# /content/drive
# Mounted at /content/drive

# %%
path = 'MyDrive/GitHub-v11'

# %% [markdown]
# # git clone

# %%
# !git config --global user.email "kang.li@maths.ox.ac.uk"
# !git config --global user.name "KangOxford"
# Clone github repository setup
# import join used to join ROOT path and MY_GOOGLE_DRIVE_PATH
from os.path import join  

# path to your project on Google Drive
MY_GOOGLE_DRIVE_PATH =  path
# replace with your Github username 
GIT_USERNAME = "KangOxford" 
# definitely replace with your
# GIT_TOKEN = "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"  
GIT_TOKEN = "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"  
# Replace with your github repository in this case we want 
# to clone deep-learning-v2-pytorch repository
GIT_REPOSITORY = "GAIL-Fail" 

PROJECT_PATH = join(ROOT, MY_GOOGLE_DRIVE_PATH)

# It's good to print out the value if you are not sure 
print("PROJECT_PATH: ", PROJECT_PATH)   

# In case we haven't created the folder already; we will create a folder in the project path 
# !mkdir "{PROJECT_PATH}"    

#GIT_PATH = "https://{GIT_TOKEN}@github.com/{GIT_USERNAME}/{GIT_REPOSITORY}.git" this return 400 Bad Request for me
GIT_PATH = "https://" + GIT_TOKEN + "@github.com/" + GIT_USERNAME + "/" + GIT_REPOSITORY + ".git"
print("GIT_PATH: ", GIT_PATH)
# Out:
# PROJECT_PATH:  /content/drive/MyDrive/GitHub-v11
# GIT_PATH:  https://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@github.com/KangOxford/GAIL-Fail.git

# %%
# %cd "{PROJECT_PATH}"
# Out:
# /content/drive/MyDrive/GitHub-v11

# %%
# !git clone "{GIT_PATH}"
# Out:
# Cloning into 'GAIL-Fail'...
# remote: Enumerating objects: 1430, done.
# remote: Counting objects: 100% (1430/1430), done.
# remote: Compressing objects: 100% (840/840), done.
# remote: Total 1430 (delta 587), reused 1405 (delta 572), pack-reused 0
# Receiving objects: 100% (1430/1430), 171.40 MiB | 18.97 MiB/s, done.
# Resolving deltas: 100% (587/587), done.
# Checking out files: 100% (165/165), done.

# %% [markdown]
# # colab vscode

# %%
name = "GAIL-Fail"
# !pip install python-dotenv --quiet
import dotenv
import os
dotenv.load_dotenv(
        os.path.join('/content/drive/MyDrive/vscode-ssh', '.env')
    )
password = os.getenv('Aa121314-')
github_access_token = os.getenv('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')
git_repo = 'https://github.com/KangOxford/'+ name

# %%
# Install colab_ssh on google colab
# !pip install colab_ssh --upgrade --quiet
from colab_ssh import launch_ssh_cloudflared, init_git_cloudflared

# %% [markdown]
# ## relaunch

# %%
launch_ssh_cloudflared(password = "Aa121314-")
# Out:
# <style>
# *{
# 	outline:none;
# }
# code{
# 	display:inline-block;
# 	padding:5px 10px;
# 	background: #444;
# 	border-radius: 4px;
# 	white-space: pre-wrap;
# 	position:relative;
# 	color:white;
# }
# .copy-code-button{
# 	float:right;
# 	background:#333;
# 	color:white;
# 	border: none;
# 	margin: 0 0 0 10px;
# 	cursor: pointer;
# }
# p, li{
# 	max-width:700px;
# }
# .choices{
# 	display:flex;
# 	flex: 1 0 auto;
# }
# .choice-section{
# 	border:solid 1px #555;
# 	border-radius: 4px;
# 	min-width:300px;
# 	margin: 10px 15px 0 0;
# 	padding: 0 15px 15px 15px ;
# }
# .button{
# 	padding: 10px 15px;
# 	background:#333;
# 	border-radius: 4px;
# 	border:solid 1px #555;
# 	color:white;
# 	font-weight:bold;
# 	cursor:pointer;
# }
# .pill{
# 	padding:2px 4px;
# 	border-radius: 100px;
# 	background-color:#e65858;
# 	font-size:12px;
# 	font-weight:bold;
# 	margin: 0 15px;
# 	color:white;
# }
# </style>
# <details class="choice-section">
# 	<summary style="cursor:pointer">
# ...

# %% [markdown]
# # run the lab

# %% [markdown]
# ## 00.Setup_Path

# %%
# %cd /content/drive/$path/GAIL-Fail/project_2022_05_06
# Out:
# /content/drive/MyDrive/GitHub-v11/GAIL-Fail/project_2022_05_06

# %% [markdown]
# ## 01.setup.sh

# %%
# !sudo apt-get install -y \
    libgl1-mesa-dev \
    libgl1-mesa-glx \
    libglew-dev \
    libosmesa6-dev \
    software-properties-common

# !sudo apt-get install -y patchelf

# !pip install -U tensorflow-probability==0.6.0
# !pip install tensorflow==1.13.1
# !pip install gym==0.15.6
# !pip install free-mujoco-py
# !pip install numpy
# !pip install pyyaml
# !pip install termcolor
# !pip install json_tricks
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libgl1-mesa-dev is already the newest version (20.0.8-0ubuntu1~18.04.1).
# libgl1-mesa-dev set to manually installed.
# software-properties-common is already the newest version (0.96.24.32.18).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# Suggested packages:
#   glew-utils
# The following NEW packages will be installed:
#   libgl1-mesa-glx libglew-dev libglew2.0 libosmesa6 libosmesa6-dev
# 0 upgraded, 5 newly installed, 0 to remove and 49 not upgraded.
# Need to get 2,916 kB of archives.
# After this operation, 12.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgl1-mesa-glx amd64 20.0.8-0ubuntu1~18.04.1 [5,532 B]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libglew2.0 amd64 2.0.0-5 [140 kB]
# ...

# %% [markdown]
# ## 02.run_sac.sh

# %%
# !pwd
# Out:
# /content/drive/MyDrive/GitHub-v11/GAIL-Fail/project_2022_05_06

# %%
import datetime
starttime = datetime.datetime.now()
print(starttime)
# Out:
# 2022-07-24 17:14:51.921839

# %%
# !bash ./scripts/run_sac.sh
# Out:
# Streaming output truncated to the last 5000 lines.
# + sleep 2
# + python3 -m sac.main -s algorithm=sac seed=300 env.id=Walker2d-v2 env.num_env=1 env.env_type=sac
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# ...

# %%
endtime = datetime.datetime.now()
print(endtime)
print((endtime - starttime).seconds)

# %% [markdown]
# ## 03.run_collect.sh

# %%
# !pwd
# Out:
# /content/drive/MyDrive/GitHub-v10/GAIL-Fail/project_2022_05_06

# %%
import datetime
starttime = datetime.datetime.now()
print(starttime)
# Out:
# 2022-07-21 22:29:12.305464

# %%
# !bash ./run_collect.sh
# Out:
# + env=Walker2d-v2
# + env_type=sac
# + policy_load=/content/drive/MyDrive/GitHub-v10/GAIL-Fail/project_2022_05_06/logs/new/sac-Walker2d-v2-200-2022-07-20-12-00-13/final.npy
# ++ uname
# + '[' Linux == Darwin ']'
# ++ uname
# + '[' Linux == Linux ']'
# + python collect.py -s algorithm=collect env.id=Walker2d-v2 env.env_type=sac ckpt.policy_load=/content/drive/MyDrive/GitHub-v10/GAIL-Fail/project_2022_05_06/logs/new/sac-Walker2d-v2-200-2022-07-20-12-00-13/final.npy
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# ...

# %%
endtime = datetime.datetime.now()
print(endtime)
print((endtime - starttime).seconds)
# Out:
# 2022-07-21 16:58:06.978817
# 115

# %% [markdown]
# ## 03.02 h5 => tf file

# %%
# !python -m gail.utils.replay_buffer --env_name="Walker2d-v2" --data_dir="dataset/sac/"
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %% [markdown]
# ## 04.run_gail.sh

# %%
# !pwd
# Out:
# /content/drive/MyDrive/GitHub-v10/GAIL-Fail/project_2022_05_06

# %%
import datetime
starttime = datetime.datetime.now()
print(">>> StartTime : ",starttime)
# !bash ./scripts/run_gail.sh
endtime = datetime.datetime.now()
print(">>> EndTime : ",endtime)
print(">>> PeriodTime : ",(endtime - starttime).seconds/3600)
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# 2022-07-22 16:28:23,679060 - gail/main.py:174 - [TRPO] iter = 2201000 dist_mean = 0.3139 dist_std = 0.1347 vf_loss = 0.0110 grad_norm = 5.1127 nat_grad_norm = 0.1326 cg_residual = 8.7825 step_size = 0.2622 reward = 0.0000 fps = 283 mse_loss = 1.4143
# 2022-07-22 16:28:24,319287 - gail/main.py:174 - [TRPO] iter = 1454000 dist_mean = 0.3572 dist_std = 0.1865 vf_loss = 0.1208 grad_norm = 4.1225 nat_grad_norm = 0.0987 cg_residual = 2.2419 step_size = 0.3827 reward = -0.0000 fps = 50 mse_loss = 0.3571
# 2022-07-22 16:28:24,865040 - gail/main.py:174 - [TRPO] iter = 2202000 dist_mean = 0.1751 dist_std = 0.1345 vf_loss = 0.0352 grad_norm = 4.1554 nat_grad_norm = 0.1486 cg_residual = 6.6054 step_size = 0.2825 reward = -0.0000 fps = 212 mse_loss = 1.4133
# ...

# %% [markdown]
# ## 05.result_plotter.py

# %%
# !python3 result_plotter.py --root_dir "/content/drive/MyDrive/GitHub-v10/GAIL-Fail/project_2022_05_06/logs/Gail_result-v3"
# Out:
# load /content/drive/MyDrive/GitHub-v10/GAIL-Fail/project_2022_05_06/logs/Gail_result-v3/gail_w-Walker2d-v2-200-2022-07-22-15-15-19/progress.csv successful
# load /content/drive/MyDrive/GitHub-v10/GAIL-Fail/project_2022_05_06/logs/Gail_result-v3/gail_w-Walker2d-v2-300-2022-07-22-15-15-19/progress.csv successful
# load /content/drive/MyDrive/GitHub-v10/GAIL-Fail/project_2022_05_06/logs/Gail_result-v3/gail_w-Walker2d-v2-100-2022-07-22-15-15-19/progress.csv successful
# load 3 results
# Walker2d-v2 gail_w 1352.6648424271305 657.4584737239583
# save result fig into /content/drive/MyDrive/GitHub-v10/GAIL-Fail/project_2022_05_06/logs/Gail_result-v3/2022-07-24 17:06:26.790380result.png

# %% [markdown]
# # Error Fixing

# %% [markdown]
# ## error of not full content of the repositry
# ### it can be fixed by removing cd to the repositry path

# %% [markdown]
# ## error of failing to connect to the vscode
# ### it  can be solved by reinstalling vscode

# %%
rm -fr ~/Library/Preferences/com.microsoft.VSCode.helper.plist 
rm -fr ~/Library/Preferences/com.microsoft.VSCode.plist 
rm -fr ~/Library/Caches/com.microsoft.VSCode
rm -fr ~/Library/Caches/com.microsoft.VSCode.ShipIt/
rm -fr ~/Library/Application\ Support/Code/
rm -fr ~/Library/Saved\ Application\ State/com.microsoft.VSCode.savedState/
rm -fr ~/.vscode/

# %% [markdown]
# # commit changes and push changes

# %%
# %cd "{PROJECT_PATH}/{GIT_REPOSITORY}" 
# %ls
# Out:
# [Errno 2] No such file or directory: '{PROJECT_PATH}/{GIT_REPOSITORY}'
# /content/drive/MyDrive/GitHub-v10/GAIL-Fail/project_2022_05_06
# acer/                                logs/              sac/
# airl/                                lunzi/             scripts/
# Archieved_GAIL-Lab_2022_05_06.ipynb  mbrl/              setup.sh
# collect.py                           README.md          td3/
# dataset/                             requirements.txt   trpo/
# evaluate.py                          result_plotter.py  utils/
# gail/                                run_collect.sh
# GAIL-Lab_2022_07_08.py               run_evaluate.sh

# %%
# !echo ref: refs/heads/master >.git/HEAD

# %%
# !git rm -r --cached .
# Out:
# fatal: pathspec '.' did not match any files

# %%
# !git branch -a
# Out:
# fatal: Failed to resolve HEAD as a valid ref.

# %%
# !git branch -r
# Out:
# fatal: Failed to resolve HEAD as a valid ref.

# %%
# !git fetch

# %%
# !git add .

# %%
# !git stash
# Out:
# Saved working directory and index state WIP on main: 773ef5c Update from Colab

# %%
# !git pull
# Out:
# error: You have not concluded your merge (MERGE_HEAD exists).
# hint: Please, commit your changes before merging.
# fatal: Exiting because of unfinished merge.

# %%
# !git checkout main
# Out:
# error: Your local changes to the following files would be overwritten by checkout:
# 	project_2022_05_06/scripts/run_sac.sh
# Please commit your changes or stash them before you switch branches.
# Aborting

# %%
# !git config --global user.email "kang.li@maths.ox.ac.uk"
# !git config --global user.name "KangOxford"

# %%
# !git add .

# %%
COMMIT_STRING = "Update from Colab"
# !git commit -m "{COMMIT_STRING}"
# Out:
# fatal: cannot lock ref 'HEAD': Unable to create '/content/drive/MyDrive/GitHub-v11/GAIL-Fail/.git/refs/heads/main
# r.lock': Invalid argument

# %%
# !git push origin main
# Out:
# Counting objects: 4, done.
# Delta compression using up to 8 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 26.29 KiB | 3.29 MiB/s, done.
# Total 4 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/KangOxford/Fourier-Transformer.git
#    7b2804e..8b26ef0  main -> main

# %% [markdown]
# # clean cloudflare

# %%
# !rm /content/drive/MyDrive/GitHub-v10/GAIL-Fail/project_2022_05_06/cloudflared
# !rm /content/drive/MyDrive/GitHub-v10/GAIL-Fail/project_2022_05_06/cloudflared.log
# !rm /content/drive/MyDrive/GitHub-v10/GAIL-Fail/cloudflared
# !rm /content/drive/MyDrive/GitHub-v10/GAIL-Fail/cloudflared.log
# Out:
# rm: cannot remove '/content/drive/MyDrive/GitHub3/GAIL-Fail/project_2022_05_06/cloudflared': No such file or directory
# rm: cannot remove '/content/drive/MyDrive/GitHub3/GAIL-Fail/project_2022_05_06/cloudflared.log': No such file or directory
